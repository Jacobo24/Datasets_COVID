# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from matplotlib.pyplot import rcParams

rcParams['figure.figsize'] = 16, 12
rcParams["font.weight"] = "bold"
rcParams["axes.labelweight"] = "bold"
rcParams["font.size"] = 13

# %%
df_tweets = pd.read_csv('covid.csv')
df_tweets.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df_tweets.isna().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179108 entries, 0 to 179107
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         179108 non-null  object
#  1   user_location     142337 non-null  object
#  2   user_description  168822 non-null  object
#  3   user_created      179108 non-null  object
#  4   user_followers    179108 non-null  int64
#  5   user_friends      179108 non-null  int64
#  6   user_favourites   179108 non-null  int64
#  7   user_verified     179108 non-null  bool
#  8   date              179108 non-null  object
#  9   text              179108 non-null  object
#  10  hashtags          127774 non-null  object
#  11  source            179031 non-null  object
#  12  is_retweet        179108 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 15.4+ MB

# %%
df_tweets["user_verified"].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 179103    False
# 179104    False
# 179105    False
# 179106    False
# 179107    False
# Name: user_verified, Length: 179108, dtype: bool

# %%
df_tweets["user_verified"].isna().sum()
# Out:
# 0

# %%
df_tweets["user_verified"][df_tweets["user_verified"].isna()]
# Out:
# Series([], Name: user_verified, dtype: bool)

# %%
df_tweets[1000:10000][["user_favourites", "user_followers", "user_friends", "user_verified"]]
# Out:
#       user_favourites  user_followers  user_friends  user_verified
# 1000            40046            6749          5225          False
# 1001                0              45             1          False
# 1002             1982             464           410          False
# 1003            16144            3936          4129          False
# 1004            13913            1015           741          False
# ...               ...             ...           ...            ...
# 9995             1654           35049          8505          False
# 9996            17435            2471           624          False
# 9997              257             337           164          False
# 9998               19             686             7          False
# 9999              155               3             0          False
#
# [9000 rows x 4 columns]

# %%
df_tweets.drop(df_tweets.dropna().index)
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 7               Derbyshire LPC                         NaN
# 8            Prathamesh Bendre                         NaN
# 10      Voice Of CBSE Students                         NaN
# ...                        ...                         ...
# 179096          laura l. sweet             Los Angeles, CA
# 179097               rainmaker                         NaN
# 179098               John Geer                         NaN
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 7                                                     NaN
# ...

# %%
df_tweets.drop(df_tweets.dropna().index)
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 7               Derbyshire LPC                         NaN
# 8            Prathamesh Bendre                         NaN
# 10      Voice Of CBSE Students                         NaN
# ...                        ...                         ...
# 179096          laura l. sweet             Los Angeles, CA
# 179097               rainmaker                         NaN
# 179098               John Geer                         NaN
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 7                                                     NaN
# ...

# %%
df_tweets.shape[0] - 79970
# Out:
# 99138

# %%
df_covid = df_tweets.dropna().reset_index(drop=True)
df_covid.head()
# Out:
#           user_name         user_location  \
# 0   Time4fisticuffs      Pewee Valley, KY
# 1       ethel mertz  Stuck in the Middle
# 2          DIPR-J&K     Jammu and Kashmir
# 3  🎹 Franz Schubert           Новоро́ссия
# 4      hr bartender       Gainesville, FL
#
#                                     user_description         user_created  \
# 0  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 1  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 2  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
# 3  🎼  #Новоро́ссия #Novorossiya #оставайсядома #S...  2018-03-19 16:29:52
# 4  Workplace tips and advice served up in a frien...  2008-08-12 18:19:49
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0            9275          9525             7254          False
# 1             197           987             1488          False
# 2          101009           168              101          False
# ...

# %%
df_covid.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    9.913800e+04   99138.000000     9.913800e+04
# mean     1.550841e+05    2374.224334     1.517543e+04
# std      1.012846e+06   10019.923883     4.490681e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      3.220000e+02     210.000000     3.330000e+02
# 50%      1.546000e+03     666.000000     2.184000e+03
# 75%      7.576000e+03    1951.000000     1.038475e+04
# max      2.435916e+07  497363.000000     2.047197e+06

# %%
df_covid.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
df_covid.dtypes[df_covid.dtypes == "object"]
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# date                object
# text                object
# hashtags            object
# source              object
# dtype: object

# %%
df_covid["user_name"].value_counts()
# Out:
# covidnews.ch                                    402
# GlobalPandemic.NET                              320
# Blood Donors India                              282
# Hindustan Times                                 267
# IANS Tweets                                     228
#                                                ...
# Julia C. Reinhart                                 1
# Mohammad Y. Al-Bahar (The Diabetic Traveler)      1
# wyoming4paul (I,you,he,she,it,we,you,they)        1
# Mithu Maheswaranathan, MD                         1
# AJIMATI AbdulRahman O.                            1
# Name: user_name, Length: 53239, dtype: int64

# %%
columnas_drop = ["user_name", "user_location", "user_description", "user_created", "date", "hashtags", "source", "text"]

# %%
df_covid2 = df_covid.drop(columns = columnas_drop, axis=1)
print("Tamaño del dataset original: ", df_covid.shape)
print("Tamaño del dataset nuevo: ", df_covid2.shape)
# Out:
# Tamaño del dataset original:  (99138, 13)
# Tamaño del dataset nuevo:  (99138, 5)

# %%
df_covid2.dtypes.value_counts()
# Out:
# int64    3
# bool     2
# dtype: int64

# %%
target = "user_verified"
features = [x for x in df_covid2.columns if x != target]

print ("Features: ", features)
print ("Target: ", target)
# Out:
# Features:  ['user_followers', 'user_friends', 'user_favourites', 'is_retweet']
# Target:  user_verified

# %%
df_covid2[target]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99133    False
# 99134    False
# 99135    False
# 99136    False
# 99137    False
# Name: user_verified, Length: 99138, dtype: bool

# %%
from sklearn.tree import DecisionTreeRegressor

arbol_importancia = DecisionTreeRegressor(max_depth=len(features)+10, random_state=42)

arbol_importancia.fit(X=df_covid2[features], y=df_covid2[target])
# Out:
# DecisionTreeRegressor(max_depth=14, random_state=42)

# %%
y_pred_arbol = arbol_importancia.predict(X=df_covid2[features])

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print('Mean Absolute Error:', mean_absolute_error(df_covid2[target], y_pred_arbol))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(df_covid2[target], y_pred_arbol)*100)
print('Mean Squared Error:', mean_squared_error(df_covid2[target], y_pred_arbol))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(df_covid2[target], y_pred_arbol)))
print('R^2 coefficient of determination:', r2_score(df_covid2[target], y_pred_arbol))
# Out:
# Mean Absolute Error: 0.051522814138772834
# Mean Absolute Percentage Error: 1.160190632782284e+16
# Mean Squared Error: 0.025761407069386427
# Root Mean Squared Error: 0.16050360453705215
# R^2 coefficient of determination: 0.8088387434206572
