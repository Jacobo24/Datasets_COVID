# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from matplotlib.pyplot import rcParams

rcParams['figure.figsize'] = 16, 12
rcParams["font.weight"] = "bold"
rcParams["axes.labelweight"] = "bold"
rcParams["font.size"] = 13

# %%
df_tweets = pd.read_csv('covid.csv')
df_tweets.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df_tweets.isna().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179108 entries, 0 to 179107
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         179108 non-null  object
#  1   user_location     142337 non-null  object
#  2   user_description  168822 non-null  object
#  3   user_created      179108 non-null  object
#  4   user_followers    179108 non-null  int64
#  5   user_friends      179108 non-null  int64
#  6   user_favourites   179108 non-null  int64
#  7   user_verified     179108 non-null  bool
#  8   date              179108 non-null  object
#  9   text              179108 non-null  object
#  10  hashtags          127774 non-null  object
#  11  source            179031 non-null  object
#  12  is_retweet        179108 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 15.4+ MB

# %%
df_tweets["user_favourites"].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 179103    False
# 179104    False
# 179105    False
# 179106    False
# 179107    False
# Name: user_favourites, Length: 179108, dtype: bool

# %%
df_tweets["user_favourites"].isna().sum()
# Out:
# 0

# %%
df_tweets["user_favourites"][df_tweets["user_favourites"].isna()]
# Out:
# Series([], Name: user_favourites, dtype: int64)

# %%
df_tweets[1000:10000][["user_favourites", "user_followers", "user_friends"]]
# Out:
#       user_favourites  user_followers  user_friends
# 1000            40046            6749          5225
# 1001                0              45             1
# 1002             1982             464           410
# 1003            16144            3936          4129
# 1004            13913            1015           741
# ...               ...             ...           ...
# 9995             1654           35049          8505
# 9996            17435            2471           624
# 9997              257             337           164
# 9998               19             686             7
# 9999              155               3             0
#
# [9000 rows x 3 columns]

# %%
df_tweets.drop(df_tweets.dropna().index)
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 7               Derbyshire LPC                         NaN
# 8            Prathamesh Bendre                         NaN
# 10      Voice Of CBSE Students                         NaN
# ...                        ...                         ...
# 179096          laura l. sweet             Los Angeles, CA
# 179097               rainmaker                         NaN
# 179098               John Geer                         NaN
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 7                                                     NaN
# ...
